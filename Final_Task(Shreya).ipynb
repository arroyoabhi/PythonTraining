# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Task-1
# - add the above two arrays
# - multiply each element of the array with 2 after addition

# %%
age1 = [2,3,4,6,5]
age2= [4,6,7,8,9]
print(f'List of elements in age1: {age1}\n')
print(f'List of elements in age2: {age2}\n')

addAge=np.add(age1, age2) 
print(f'After adding above 2 arrays: {addAge}\n')

mul = np.array(addAge)
print (f'After multiplying each element with 2: {mul * 2}')
# Out:
# List of elements in age1: [2, 3, 4, 6, 5]
#
# List of elements in age2: [4, 6, 7, 8, 9]
#
# After adding above 2 arrays: [ 6  9 11 14 14]
#
# After multiplying each element with 2: [12 18 22 28 28]

# %%
age1 = [2,3,4,6,5]
age2= [4,6,7,8,9]
  
print ("List of elements in age1: ",age1)
print ("\nList of elements in age2: ",age2)
  

age = []
for i in range(0, len(age1)):
    age.append(age1[i] + age2[i])
print ("\nAfter adding above 2 arrays : ",age)

mul = [x*2 for x in age]
print("\nAfter multiplying each element with 2 :",mul)
# Out:
# List of elements in age1:  [2, 3, 4, 6, 5]
#
# List of elements in age2:  [4, 6, 7, 8, 9]
#
# After adding above 2 arrays :  [6, 9, 11, 14, 14]
#
# After multiplying each element with 2 : [12, 18, 22, 28, 28]

# %% [markdown]
# # Task-2
# - *print last 4 values*
# - *print 2nd to 3rd position value from last*

# %%
arr = np.array([1,2,3,8,5,6,7])
print(f'The last 4 values are:{arr[-4:]}')
print(f'The values of 2nd to 3rd positions from last are: {arr[-2]},{arr[-3]}.')
# Out:
# The last 4 values are:[8 5 6 7]
# The values of 2nd to 3rd positions from last are: 6,5.

# %% [markdown]
# # Task-3
# ### Handling dates
# - Find how much time it takes to place an order and ship the product
# - How many times has it taken more than 5 days from placing an order to shipping

# %%
data=pd.read_csv('Store.csv',header=0,encoding="latin")
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156  11-09-2013  11-12-2013    Second Class    CG-12520
# 1       2  CA-2013-152156  11-09-2013  11-12-2013    Second Class    CG-12520
# 2       3  CA-2013-138688   6/13/2013   6/17/2013    Second Class    DV-13045
# 3       4  US-2012-108966  10-11-2012  10/18/2012  Standard Class    SO-20335
# 4       5  US-2012-108966  10-11-2012  10/18/2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### Converting all the dates to date format

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])
data['Ship Date'] = pd.to_datetime(data['Ship Date'])
data
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 1          2  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 2          3  CA-2013-138688 2013-06-13 2013-06-17    Second Class
# 3          4  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 4          5  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2011-110422 2011-01-22 2011-01-24    Second Class
# 9990    9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9991    9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9992    9993  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9993    9994  CA-2014-119914 2014-05-05 2014-05-10    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# ### Adding a seperate column 'Shipping Days' containing the number of days from placing an order till shipping the product

# %%
data['ShippingDays'] = (data['Ship Date'] - data['Order Date'])
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2       3  CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3       4  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4       5  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### Converting to from Shipping days from timedelta to int data type.

# %%
data['ShippingDays'] = (data['ShippingDays']).dt.days
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2       3  CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3       4  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4       5  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
#data['Shipping Days'] = (data['Ship Date'] - data['Order Date']).dt.days
#data.head()

# %% [markdown]
# ### Number of times it taken more than 5 days from placing an order to shipping

# %%
c=data['ShippingDays'] > 5
c.value_counts()
# Out:
# False    8172
# True     1822
# Name: ShippingDays, dtype: int64

# %%
data[data.ShippingDays > 5].count()
# Out:
# Row ID           1822
# Order ID         1822
# Order Date       1822
# Ship Date        1822
# Ship Mode        1822
# Customer ID      1822
# Customer Name    1822
# Segment          1822
# Country          1822
# City             1822
# State            1822
# Postal Code      1822
# Region           1822
# Product ID       1822
# Category         1822
# Sub-Category     1822
# Product Name     1822
# Sales            1822
# Quantity         1822
# Discount         1822
# Profit           1822
# ShippingDays     1822
# dtype: int64

# %%
data[data['ShippingDays'] > 5]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 3          4  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 4          5  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 16        17  CA-2011-105893 2011-11-11 2011-11-18  Standard Class
# 53        54  CA-2013-105816 2013-12-12 2013-12-18  Standard Class
# 54        55  CA-2013-105816 2013-12-12 2013-12-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9972    9973  CA-2013-130225 2013-09-12 2013-09-18  Standard Class
# 9982    9983  US-2013-157728 2013-09-23 2013-09-29  Standard Class
# 9983    9984  US-2013-157728 2013-09-23 2013-09-29  Standard Class
# 9984    9985  CA-2012-100251 2012-05-17 2012-05-23  Standard Class
# 9985    9986  CA-2012-100251 2012-05-17 2012-05-23  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...

# %% [markdown]
# # Task-4
# ## PieChart

# %% [markdown]
# ### Piechart for Ship Mode

# %%
data['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
#data['Ship Mode'].value_counts().plot(kind='pie',title='Ship Mode');
import matplotlib.pyplot as plt
myexplode = [0, 0.1, 0, 0]
mycolors = ["y", "pink","#3CeF60","hotpink"]
mylabels = ["Standard Class", "Second Class", "First Class", "Same Day"]

plt.pie(data['Ship Mode'].value_counts(),labels=mylabels,explode = myexplode,shadow = True,colors = mycolors,autopct='%2.1f%%');
plt.legend(title = "Ship Mode:")
plt.show()

# %% [markdown]
# ### Piechart for Segment

# %%
data['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
#data['Segment'].value_counts().plot(kind='pie', title='Segment',explode = myexplode,shadow = True,colors = mycolors);
import matplotlib.pyplot as plt
myexplode = [0, 0, 0.1]
mycolors = ["skyblue", "hotpink","#4CAF50"]
mylabels = ["Consumer", "Corporate", "Home Office"]

plt.pie(data['Segment'].value_counts(),labels=mylabels,explode = myexplode,shadow = True,colors = mycolors, autopct='%2.1f%%');
plt.legend(title = "Segment:")
plt.show()

# %% [markdown]
# ### Piechart for Region

# %%
data['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
#data['Region'].value_counts().plot(kind='pie', title='Region');
import matplotlib.pyplot as plt
myexplode = [0, 0, 0.1, 0]
mycolors = ["#FFC0CB", "Olive","#00FFFF","g"]
mylabels = ["West", "East", "Central", "South"]

plt.pie(data['Region'].value_counts(),labels=mylabels,explode = myexplode,shadow = True,colors = mycolors, autopct='%2.1f%%');
plt.show()

# %% [markdown]
# ### Piechart for Category

# %%
data['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
#data['Category'].value_counts().plot(kind='pie',title='Category');
import matplotlib.pyplot as plt
myexplode = [0, 0, 0.4]
mycolors = ["Orange", "#FFC0CB","Gray"]
mylabels = ["Office Supplies", "Furniture", "Technology"]

plt.pie(data['Category'].value_counts(),labels=mylabels,explode = myexplode,shadow = True,colors = mycolors, autopct='%2.1f%%');
plt.legend(title = "Segment:")
plt.show()

# %%
data['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
import matplotlib.pyplot as plt
marks=[33,21,50,32,54]
Students=['Shreya','Sunny','Priya','Sanjay','Shannu']
exp=[0,0,0.1,0,0]

plt.pie(marks, labels=Students, explode=exp, autopct='%2.1f%%')
plt.show()
